# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

def plot_demo():
    #print(mpl.get_cachedir())
    # 绘制折线图
    plt.rcParams["font.sans-serif"] = ["SimHei"]  # 设置字体
    plt.rcParams["axes.unicode_minus"] = False  # 正常显示负号
    year = [2017, 2018, 2019, 2020]
    people = [20, 40, 60, 70]
    # 生成图表
    plt.plot(year, people)
    plt.xlabel('年份')
    plt.ylabel('人口')
    plt.title('人口增长')
    # 设置纵坐标刻度
    plt.yticks([0, 20, 40, 60, 80])
    # 设置填充选项：参数分别对应横坐标，纵坐标，纵坐标填充起始值，填充颜色
    plt.fill_between(year, people, 20, color='green')
    # 显示图表
    # plt.savefig("./plt.png")
    plt.show()

plot_demo()

# %%
from collections import deque

# 创建一个长度为10的队列
queue = deque(maxlen=10)

# 假设队列中有一些元素，这里只是举例
# 添加一些示例元素
queue.append([1, 2])
queue.append([3, 4])
queue.append([5, 6])

# 将队列转换为列表
center_list = list(queue)

# 计算center_x和center_y的总和
sum_x = sum(center[0] for center in center_list)
sum_y = sum(center[1] for center in center_list)
print("sum_x ",sum_x)
print("sum_y ",sum_y)

# 计算平均值
average_x = sum_x / len(center_list)
average_y = sum_y / len(center_list)

# 返回平均值
print("Average center_x:", average_x)
print("Average center_y:", average_y)
# Out:
# sum_x  9
# sum_y  12
# Average center_x: 3.0
# Average center_y: 4.0
